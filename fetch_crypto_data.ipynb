# %%
import datetime
import json
import csv
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import http.client

conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets", payload, headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# {"data":[{"id":"bitcoin","rank":"1","symbol":"BTC","name":"Bitcoin","supply":"19658368.0000000000000000","maxSupply":"21000000.0000000000000000","marketCapUsd":"1379513097060.8613396067500160","volumeUsd24Hr":"10908730117.6776908017221356","priceUsd":"70174.3449436322150245","changePercent24Hr":"-0.2256033519804800","vwap24Hr":"70422.7971343398502476","explorer":"https://blockchain.info/"},{"id":"ethereum","rank":"2","symbol":"ETH","name":"Ethereum","supply":"120077426.1898597300000000","maxSupply":null,"marketCapUsd":"432168894230.9934843796600451","volumeUsd24Hr":"7142730555.2392284256475955","priceUsd":"3599.0852564383927529","changePercent24Hr":"-0.3463443328192875","vwap24Hr":"3611.1720476718773718","explorer":"https://etherscan.io/"},{"id":"tether","rank":"3","symbol":"USDT","name":"Tether","supply":"103618183617.7160800000000000","maxSupply":null,"marketCapUsd":"103650245149.4002196332737137","volumeUsd24Hr":"25980251189.7378620229067500","priceUsd":"1.0003094199354278","chang
# ...

# %%
# Load JSON data
extract_data = json.loads(data)

df= pd.DataFrame(extract_data['data'])
df.to_csv('final_crypto.csv', index=False, header=True)
print("CSV file has been created successfully.")
# Out:
# CSV file has been created successfully.

# %%
# Getting data for top 10 cryptocurrency

# %%
import http.client

# %%
conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets/bitcoin/history?interval=d1", payload, headers)
res = conn.getresponse()
bitcoin_data = res.read()
bitcoin_data_df= pd.DataFrame(json.loads(bitcoin_data)['data'])
bitcoin_data_df.insert(0, 'id', 'bitcoin')
bitcoin_data_df.head()
#print(bitcoin_data.decode("utf-8"))
# Out:
#         id                priceUsd           time                      date
# 0  bitcoin  27065.6706570567305529  1679961600000  2023-03-28T00:00:00.000Z
# 1  bitcoin  28118.2122209636066111  1680048000000  2023-03-29T00:00:00.000Z
# 2  bitcoin  28415.3047378586822899  1680134400000  2023-03-30T00:00:00.000Z
# 3  bitcoin  28240.9604785536354686  1680220800000  2023-03-31T00:00:00.000Z
# 4  bitcoin  28503.4131407150636311  1680307200000  2023-04-01T00:00:00.000Z

# %%
conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets/ethereum/history?interval=d1", payload, headers)
res = conn.getresponse()
ethereum_data = res.read()
ethereum_data_df= pd.DataFrame(json.loads(ethereum_data)['data'])
ethereum_data_df.insert(0, 'id', 'ethereum')
ethereum_data_df.head()
#print(ethereum_data.decode("utf-8"))
# Out:
#          id               priceUsd           time                      date
# 0  ethereum  1739.0292368627287862  1679961600000  2023-03-28T00:00:00.000Z
# 1  ethereum  1801.4126833820127581  1680048000000  2023-03-29T00:00:00.000Z
# 2  ethereum  1795.6295143492993633  1680134400000  2023-03-30T00:00:00.000Z
# 3  ethereum  1813.3800169359037036  1680220800000  2023-03-31T00:00:00.000Z
# 4  ethereum  1826.4093262631563085  1680307200000  2023-04-01T00:00:00.000Z

# %%
conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets/tether/history?interval=d1", payload, headers)
res = conn.getresponse()
tether_data = res.read()
tether_data_df= pd.DataFrame(json.loads(tether_data)['data'])
tether_data_df.insert(0, 'id', 'tether')
tether_data_df.head()
#print(tether_data.decode("utf-8"))
# Out:
#        id            priceUsd           time                      date
# 0  tether  1.0013173034346209  1679961600000  2023-03-28T00:00:00.000Z
# 1  tether  1.0013828436852405  1680048000000  2023-03-29T00:00:00.000Z
# 2  tether  1.0013466256300645  1680134400000  2023-03-30T00:00:00.000Z
# 3  tether  1.0014705124211978  1680220800000  2023-03-31T00:00:00.000Z
# 4  tether  1.0021044449504974  1680307200000  2023-04-01T00:00:00.000Z

# %%
conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets/binance-coin/history?interval=d1", payload, headers)
res = conn.getresponse()
binancecoin_data = res.read()
binancecoin_data_df= pd.DataFrame(json.loads(binancecoin_data)['data'])
binancecoin_data_df.insert(0, 'id', 'binance-coin')
binancecoin_data_df.head()
#print(binancecoin_data.decode("utf-8"))
# Out:
#              id              priceUsd           time                      date
# 0  binance-coin  311.1752753729103144  1679961600000  2023-03-28T00:00:00.000Z
# 1  binance-coin  316.0303806705048294  1680048000000  2023-03-29T00:00:00.000Z
# 2  binance-coin  315.6846105062799012  1680134400000  2023-03-30T00:00:00.000Z
# 3  binance-coin  317.1381372302450135  1680220800000  2023-03-31T00:00:00.000Z
# 4  binance-coin  315.8003101123334037  1680307200000  2023-04-01T00:00:00.000Z

# %%
conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets/solana/history?interval=d1", payload, headers)
res = conn.getresponse()
solana_data = res.read()
solana_data_df= pd.DataFrame(json.loads(solana_data)['data'])
solana_data_df.insert(0, 'id', 'solana')
solana_data_df.head()
#print(solana_data.decode("utf-8"))
# Out:
#        id             priceUsd           time                      date
# 0  solana  20.0894420019929964  1679961600000  2023-03-28T00:00:00.000Z
# 1  solana  21.0815598498377422  1680048000000  2023-03-29T00:00:00.000Z
# 2  solana  20.7576175429637652  1680134400000  2023-03-30T00:00:00.000Z
# 3  solana  20.6759191862052450  1680220800000  2023-03-31T00:00:00.000Z
# 4  solana  21.0773563090952983  1680307200000  2023-04-01T00:00:00.000Z

# %%
conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets/usd-coin/history?interval=d1", payload, headers)
res = conn.getresponse()
usdcoin_data = res.read()
usdcoin_data_df= pd.DataFrame(json.loads(usdcoin_data)['data'])
usdcoin_data_df.insert(0, 'id', 'usd-coin')
usdcoin_data_df.head()
#print(usdcoin_data.decode("utf-8"))
# Out:
#          id            priceUsd           time                      date
# 0  usd-coin  1.0008305265259966  1679961600000  2023-03-28T00:00:00.000Z
# 1  usd-coin  1.0009485552226599  1680048000000  2023-03-29T00:00:00.000Z
# 2  usd-coin  1.0010127628623135  1680134400000  2023-03-30T00:00:00.000Z
# 3  usd-coin  1.0010745039985466  1680220800000  2023-03-31T00:00:00.000Z
# 4  usd-coin  1.0016710553439343  1680307200000  2023-04-01T00:00:00.000Z

# %%
conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets/xrp/history?interval=d1", payload, headers)
res = conn.getresponse()
xrp_data = res.read()
xrp_data_df= pd.DataFrame(json.loads(xrp_data)['data'])
xrp_data_df.insert(0, 'id', 'xrp')
xrp_data_df.head()
#print(xrp_data.decode("utf-8"))
# Out:
#     id                priceUsd           time                      date
# 0  xrp  0.49644473941959952319  1679961600000  2023-03-28T00:00:00.000Z
# 1  xrp  0.54707385996788949125  1680048000000  2023-03-29T00:00:00.000Z
# 2  xrp  0.53730767525084112253  1680134400000  2023-03-30T00:00:00.000Z
# 3  xrp  0.53576574274426232132  1680220800000  2023-03-31T00:00:00.000Z
# 4  xrp  0.51744670657903498549  1680307200000  2023-04-01T00:00:00.000Z

# %%
conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets/dogecoin/history?interval=d1", payload, headers)
res = conn.getresponse()
dogecoin_data = res.read()
dogecoin_data_df= pd.DataFrame(json.loads(dogecoin_data)['data'])
dogecoin_data_df.insert(0, 'id', 'dogecoin')
dogecoin_data_df.head()
#print(dogecoin_data.decode("utf-8"))
# Out:
#          id                priceUsd           time                      date
# 0  dogecoin  0.07280267959377878083  1679961600000  2023-03-28T00:00:00.000Z
# 1  dogecoin  0.07554602294796942083  1680048000000  2023-03-29T00:00:00.000Z
# 2  dogecoin  0.07494597740690707942  1680134400000  2023-03-30T00:00:00.000Z
# 3  dogecoin  0.07541751389497868715  1680220800000  2023-03-31T00:00:00.000Z
# 4  dogecoin  0.07826016095790171340  1680307200000  2023-04-01T00:00:00.000Z

# %%
conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets/cardano/history?interval=d1", payload, headers)
res = conn.getresponse()
cardano_data = res.read()
cardano_data_df= pd.DataFrame(json.loads(cardano_data)['data'])
cardano_data_df.insert(0, 'id', 'cardano')
cardano_data_df.head()
#print(cardano_data.decode("utf-8"))
# Out:
#         id                priceUsd           time                      date
# 0  cardano  0.35400470838898566903  1679961600000  2023-03-28T00:00:00.000Z
# 1  cardano  0.38206747040401236000  1680048000000  2023-03-29T00:00:00.000Z
# 2  cardano  0.37783203458557585682  1680134400000  2023-03-30T00:00:00.000Z
# 3  cardano  0.39198255868016535069  1680220800000  2023-03-31T00:00:00.000Z
# 4  cardano  0.39429185571150770278  1680307200000  2023-04-01T00:00:00.000Z

# %%
conn = http.client.HTTPSConnection("api.coincap.io")
payload = ''
headers = {}
conn.request("GET", "/v2/assets/avalanche/history?interval=d1", payload, headers)
res = conn.getresponse()
avalanche_data = res.read()
avalanche_data_df= pd.DataFrame(json.loads(avalanche_data)['data'])
avalanche_data_df.insert(0, 'id', 'avalanche')
avalanche_data_df.head()
#print(avalanche_data.decode("utf-8"))
# Out:
#           id             priceUsd           time                      date
# 0  avalanche  16.5828252945814797  1679961600000  2023-03-28T00:00:00.000Z
# 1  avalanche  17.1739784949060535  1680048000000  2023-03-29T00:00:00.000Z
# 2  avalanche  17.2979592139591408  1680134400000  2023-03-30T00:00:00.000Z
# 3  avalanche  17.4647783019206255  1680220800000  2023-03-31T00:00:00.000Z
# 4  avalanche  17.7467024229551064  1680307200000  2023-04-01T00:00:00.000Z

# %%
final_data_time_series = pd.concat([bitcoin_data_df, ethereum_data_df, tether_data_df, binancecoin_data_df,
                                  solana_data_df, usdcoin_data_df, xrp_data_df,dogecoin_data_df, 
                                   cardano_data_df,avalanche_data_df], ignore_index = True)
final_data_time_series.head()
# Out:
#         id                priceUsd           time                      date
# 0  bitcoin  27065.6706570567305529  1679961600000  2023-03-28T00:00:00.000Z
# 1  bitcoin  28118.2122209636066111  1680048000000  2023-03-29T00:00:00.000Z
# 2  bitcoin  28415.3047378586822899  1680134400000  2023-03-30T00:00:00.000Z
# 3  bitcoin  28240.9604785536354686  1680220800000  2023-03-31T00:00:00.000Z
# 4  bitcoin  28503.4131407150636311  1680307200000  2023-04-01T00:00:00.000Z

# %%
final_data_time_series.tail()
# Out:
#              id             priceUsd           time                      date
# 3635  avalanche  54.9919416615477766  1710979200000  2024-03-21T00:00:00.000Z
# 3636  avalanche  54.3824265812230237  1711065600000  2024-03-22T00:00:00.000Z
# 3637  avalanche  54.4054325224182931  1711152000000  2024-03-23T00:00:00.000Z
# 3638  avalanche  53.8898021996736862  1711238400000  2024-03-24T00:00:00.000Z
# 3639  avalanche  57.2385773566666628  1711324800000  2024-03-25T00:00:00.000Z

# %%
final_data_time_series.to_csv('final_data_time_series.csv', index=False, header=True)
print("CSV file has been created successfully.")
# Out:
# CSV file has been created successfully.

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('final_data_time_series.csv')

# Convert the date column to datetime
df['date'] = pd.to_datetime(df['date'])

# Extract the date and store it in another column
df['extracted_date'] = df['date'].dt.date

# Save the modified DataFrame back to a new CSV file
df.to_csv('final_time_series_data.csv', index=False)

print("Date extraction and saving to new CSV file is complete.")
# Out:
# Date extraction and saving to new CSV file is complete.

# %%
#Convert date to datetime format  and price to float format for all crypto currencies

# %%
# Convert the date column to datetime
bitcoin_data_df['date'] = pd.to_datetime(bitcoin_data_df['date'])

# Extract the date and store it in another column
bitcoin_data_df['extracted_date'] = bitcoin_data_df['date'].dt.date

#convert priceUsd to float
bitcoin_data_df['priceUsd']=bitcoin_data_df['priceUsd'].astype(float)

bitcoin_data_df.head()
# Out:
#         id      priceUsd           time                      date  \
# 0  bitcoin  27065.670657  1679961600000 2023-03-28 00:00:00+00:00
# 1  bitcoin  28118.212221  1680048000000 2023-03-29 00:00:00+00:00
# 2  bitcoin  28415.304738  1680134400000 2023-03-30 00:00:00+00:00
# 3  bitcoin  28240.960479  1680220800000 2023-03-31 00:00:00+00:00
# 4  bitcoin  28503.413141  1680307200000 2023-04-01 00:00:00+00:00
#
#   extracted_date
# 0     2023-03-28
# 1     2023-03-29
# 2     2023-03-30
# 3     2023-03-31
# 4     2023-04-01

# %%
# Convert the date column to datetime
ethereum_data_df['date'] = pd.to_datetime(ethereum_data_df['date'])

# Extract the date and store it in another column
ethereum_data_df['extracted_date'] = ethereum_data_df['date'].dt.date

#convert priceUsd to float
ethereum_data_df['priceUsd']=ethereum_data_df['priceUsd'].astype(float)

ethereum_data_df.head()
# Out:
#          id     priceUsd           time                      date  \
# 0  ethereum  1739.029237  1679961600000 2023-03-28 00:00:00+00:00
# 1  ethereum  1801.412683  1680048000000 2023-03-29 00:00:00+00:00
# 2  ethereum  1795.629514  1680134400000 2023-03-30 00:00:00+00:00
# 3  ethereum  1813.380017  1680220800000 2023-03-31 00:00:00+00:00
# 4  ethereum  1826.409326  1680307200000 2023-04-01 00:00:00+00:00
#
#   extracted_date
# 0     2023-03-28
# 1     2023-03-29
# 2     2023-03-30
# 3     2023-03-31
# 4     2023-04-01

# %%
# Convert the date column to datetime
tether_data_df['date'] = pd.to_datetime(tether_data_df['date'])

# Extract the date and store it in another column
tether_data_df['extracted_date'] = tether_data_df['date'].dt.date

#convert priceUsd to float
tether_data_df['priceUsd']=tether_data_df['priceUsd'].astype(float)

tether_data_df.head()
# Out:
#        id  priceUsd           time                      date extracted_date
# 0  tether  1.001317  1679961600000 2023-03-28 00:00:00+00:00     2023-03-28
# 1  tether  1.001383  1680048000000 2023-03-29 00:00:00+00:00     2023-03-29
# 2  tether  1.001347  1680134400000 2023-03-30 00:00:00+00:00     2023-03-30
# 3  tether  1.001471  1680220800000 2023-03-31 00:00:00+00:00     2023-03-31
# 4  tether  1.002104  1680307200000 2023-04-01 00:00:00+00:00     2023-04-01

# %%
# Convert the date column to datetime
binancecoin_data_df['date'] = pd.to_datetime(binancecoin_data_df['date'])

# Extract the date and store it in another column
binancecoin_data_df['extracted_date'] = binancecoin_data_df['date'].dt.date

#convert priceUsd to float
binancecoin_data_df['priceUsd']=binancecoin_data_df['priceUsd'].astype(float)

binancecoin_data_df.head()
# Out:
#              id    priceUsd           time                      date  \
# 0  binance-coin  311.175275  1679961600000 2023-03-28 00:00:00+00:00
# 1  binance-coin  316.030381  1680048000000 2023-03-29 00:00:00+00:00
# 2  binance-coin  315.684611  1680134400000 2023-03-30 00:00:00+00:00
# 3  binance-coin  317.138137  1680220800000 2023-03-31 00:00:00+00:00
# 4  binance-coin  315.800310  1680307200000 2023-04-01 00:00:00+00:00
#
#   extracted_date
# 0     2023-03-28
# 1     2023-03-29
# 2     2023-03-30
# 3     2023-03-31
# 4     2023-04-01

# %%
# Convert the date column to datetime
solana_data_df['date'] = pd.to_datetime(solana_data_df['date'])

# Extract the date and store it in another column
solana_data_df['extracted_date'] = solana_data_df['date'].dt.date

#convert priceUsd to float
solana_data_df['priceUsd']=solana_data_df['priceUsd'].astype(float)

solana_data_df.head()
# Out:
#        id   priceUsd           time                      date extracted_date
# 0  solana  20.089442  1679961600000 2023-03-28 00:00:00+00:00     2023-03-28
# 1  solana  21.081560  1680048000000 2023-03-29 00:00:00+00:00     2023-03-29
# 2  solana  20.757618  1680134400000 2023-03-30 00:00:00+00:00     2023-03-30
# 3  solana  20.675919  1680220800000 2023-03-31 00:00:00+00:00     2023-03-31
# 4  solana  21.077356  1680307200000 2023-04-01 00:00:00+00:00     2023-04-01

# %%
# Convert the date column to datetime
usdcoin_data_df['date'] = pd.to_datetime(usdcoin_data_df['date'])

# Extract the date and store it in another column
usdcoin_data_df['extracted_date'] = usdcoin_data_df['date'].dt.date

#convert priceUsd to float
usdcoin_data_df['priceUsd']=usdcoin_data_df['priceUsd'].astype(float)

usdcoin_data_df.head()
# Out:
#          id  priceUsd           time                      date extracted_date
# 0  usd-coin  1.000831  1679961600000 2023-03-28 00:00:00+00:00     2023-03-28
# 1  usd-coin  1.000949  1680048000000 2023-03-29 00:00:00+00:00     2023-03-29
# 2  usd-coin  1.001013  1680134400000 2023-03-30 00:00:00+00:00     2023-03-30
# 3  usd-coin  1.001075  1680220800000 2023-03-31 00:00:00+00:00     2023-03-31
# 4  usd-coin  1.001671  1680307200000 2023-04-01 00:00:00+00:00     2023-04-01

# %%
# Convert the date column to datetime
xrp_data_df['date'] = pd.to_datetime(xrp_data_df['date'])

# Extract the date and store it in another column
xrp_data_df['extracted_date'] = xrp_data_df['date'].dt.date

#convert priceUsd to float
xrp_data_df['priceUsd']=xrp_data_df['priceUsd'].astype(float)

xrp_data_df.head()
# Out:
#     id  priceUsd           time                      date extracted_date
# 0  xrp  0.496445  1679961600000 2023-03-28 00:00:00+00:00     2023-03-28
# 1  xrp  0.547074  1680048000000 2023-03-29 00:00:00+00:00     2023-03-29
# 2  xrp  0.537308  1680134400000 2023-03-30 00:00:00+00:00     2023-03-30
# 3  xrp  0.535766  1680220800000 2023-03-31 00:00:00+00:00     2023-03-31
# 4  xrp  0.517447  1680307200000 2023-04-01 00:00:00+00:00     2023-04-01

# %%
# Convert the date column to datetime
dogecoin_data_df['date'] = pd.to_datetime(dogecoin_data_df['date'])

# Extract the date and store it in another column
dogecoin_data_df['extracted_date'] = dogecoin_data_df['date'].dt.date

#convert priceUsd to float
dogecoin_data_df['priceUsd']=dogecoin_data_df['priceUsd'].astype(float)

dogecoin_data_df.head()
# Out:
#          id  priceUsd           time                      date extracted_date
# 0  dogecoin  0.072803  1679961600000 2023-03-28 00:00:00+00:00     2023-03-28
# 1  dogecoin  0.075546  1680048000000 2023-03-29 00:00:00+00:00     2023-03-29
# 2  dogecoin  0.074946  1680134400000 2023-03-30 00:00:00+00:00     2023-03-30
# 3  dogecoin  0.075418  1680220800000 2023-03-31 00:00:00+00:00     2023-03-31
# 4  dogecoin  0.078260  1680307200000 2023-04-01 00:00:00+00:00     2023-04-01

# %%
# Convert the date column to datetime
cardano_data_df['date'] = pd.to_datetime(cardano_data_df['date'])

# Extract the date and store it in another column
cardano_data_df['extracted_date'] = cardano_data_df['date'].dt.date

#convert priceUsd to float
cardano_data_df['priceUsd']=cardano_data_df['priceUsd'].astype(float)

cardano_data_df.head()
# Out:
#         id  priceUsd           time                      date extracted_date
# 0  cardano  0.354005  1679961600000 2023-03-28 00:00:00+00:00     2023-03-28
# 1  cardano  0.382067  1680048000000 2023-03-29 00:00:00+00:00     2023-03-29
# 2  cardano  0.377832  1680134400000 2023-03-30 00:00:00+00:00     2023-03-30
# 3  cardano  0.391983  1680220800000 2023-03-31 00:00:00+00:00     2023-03-31
# 4  cardano  0.394292  1680307200000 2023-04-01 00:00:00+00:00     2023-04-01
